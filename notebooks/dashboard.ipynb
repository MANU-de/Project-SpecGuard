# %%
# Cell 2: Import and Initialize
from src.engine import SpecGuardEngine

DRAFTER = "manuelaschrittwieser/specguard-drafter-lora-v1"
CRITIC = "manuelaschrittwieser/specguard-critic-lora-v1"

# This loads the models into the Colab GPU memory once
engine = SpecGuardEngine(DRAFTER, CRITIC)

# %%
# Cell 3: Run a demo task
engine.run("Update server backup status", "Files: /var/log/backup.log, /usr/bin/logger.py")

# %%
# Cell 1: Load Autoreload
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('.') # Tells Python to look for the 'src' folder
